# %%
# %matplotlib inline

import tensorflow as tf

from tensorflow.keras import datasets, layers, models

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# 픽셀 값을 0~1 사이로 정규화합니다.
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model = models.Sequential()
model.add(layers.Input((28,28,1)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 168,874 (659.66 KB)
#  Trainable params: 168,874 (659.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images,
                    train_labels,
                    batch_size=128,
                    epochs=10,
                    validation_data=(test_images,test_labels))
# Out:
# 2025-11-30 20:42:00.441489: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 188160000 exceeds 10% of free system memory.
# Epoch 1/10
# 2025-11-30 20:42:21.013048: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 17981568 exceeds 10% of free system memory.
# 2025-11-30 20:42:21.023684: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 17981568 exceeds 10% of free system memory.
#   2/469 ━━━━━━━━━━━━━━━━━━━━ 2:24 310ms/step - accuracy: 0.1016 - loss: 2.2989
# 2025-11-30 20:42:21.389420: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 17981568 exceeds 10% of free system memory.
# 2025-11-30 20:42:21.392095: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 17981568 exceeds 10% of free system memory.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 91s 163ms/step - accuracy: 0.9191 - loss: 0.2644 - val_accuracy: 0.9797 - val_loss: 0.0655
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.9809 - loss: 0.0631 - val_accuracy: 0.9864 - val_loss: 0.0428
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.9866 - loss: 0.0435 - val_accuracy: 0.9887 - val_loss: 0.0349
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 110ms/step - accuracy: 0.9897 - loss: 0.0341 - val_accuracy: 0.9893 - val_loss: 0.0346
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.9915 - loss: 0.0270 - val_accuracy: 0.9913 - val_loss: 0.0278
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 95ms/step - accuracy: 0.9929 - loss: 0.0225 - val_accuracy: 0.9894 - val_loss: 0.0368
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 101ms/step - accuracy: 0.9931 - loss: 0.0204 - val_accuracy: 0.9906 - val_loss: 0.0273
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 112ms/step - accuracy: 0.9953 - loss: 0.0158 - val_accuracy: 0.9896 - val_loss: 0.0346
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9954 - loss: 0.0145 - val_accuracy: 0.9897 - val_loss: 0.0392
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9961 - loss: 0.0118 - val_accuracy: 0.9908 - val_loss: 0.0347

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 9s - 28ms/step - accuracy: 0.9908 - loss: 0.0347

# %%
# Out:
# <keras.src.callbacks.history.History object at 0x7e3ab46276d0>
